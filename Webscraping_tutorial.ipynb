# %%
#Step 1: FSC

from bs4 import BeautifulSoup
import requests
import pandas as pd


url = 'https://lhr.nu.edu.pk/faculty/'
source = requests.get(url)

soup = BeautifulSoup(source.text, 'html.parser')

faculty_section = soup.find('div', id='fsc')
faculty_members = faculty_section.find_all('div', class_='col-lg-3 col-md-4 col-sm-6 col-12')

faculty_data = []
No=0

for member in faculty_members:

        No=No+1

        idx=member.find('a',href=True)

        name = member.find('h5', class_='text-center')

        designation = member.find('p')

        email_tag=member.find('p',class_='mb-0 text-center')

        image_tag = member.find('img')
        image_url = image_tag['src'] if image_tag else 'N/A'

        hec_supervisor = 'HEC Approved PhD Supervisor' in member.text

        print("Sr",No)
        print("ID: ",idx['href'].split('/')[-1] if idx else 'N/A')
        print("Name", name.text.strip() if name else 'N/A')
        print("Designation", designation.text.strip() if designation else 'N/A')
        print( "HEC Approved PhD Supervisor", hec_supervisor)
        print("Email", email_tag.text.strip())
        print("Department :", "FAST School of Computing")
        print("ImageURL", image_url)
        print("\n")


        faculty_data.append({
            "Sr": No,
            "ID: ":idx['href'].split('/')[-1] if idx else 'N/A',
            "Name": name.text.strip() if name else 'N/A',
            "Designation": designation.text.strip() if designation else 'N/A',
            "HEC Approved PhD Supervisor": hec_supervisor,
            "Email": email_tag.text.strip(),
            "Department": "FAST School of Computing",
            "ImageURL": image_url
        })

df = pd.DataFrame(faculty_data)

df.to_csv('fsc.csv',index=False)

print("Data saved to fsc.csv😃")
# Out:
# Sr 1
# ID:  1238
# Name Dr. Kashif Zafar
# Designation Professor & HOD
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email kashif.zafar@nu.edu.pk
# Department : FAST School of Computing
# ImageURL /media/Faculty/01._Dr_Kashif_Zafar_Prof._CS.JPG
#
#
# Sr 2
# ID:  4027
# Name Dr. Aamir Wali
# Designation Professor
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email aamir.wali@nu.edu.pk
# Department : FAST School of Computing
# ImageURL /media/Faculty/51._Dr_Aamir_Wali_Prof._AIDS.JPG
#
#
# Sr 3
# ID:  4391
# Name Dr. Asif Mahmood Gillani
# Designation Professor
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email asif.gilani@nu.edu.pk
# Department : FAST School of Computing
# ImageURL /media/Faculty/02._Dr_Asif_Mehmood_Gilani_Prof._CS.JPG
#
#
# Sr 4
# ID:  6113
# Name Dr. Asma Naseer
# Designation Professor
#
# ...

# %%
#Step 1: EE

from bs4 import BeautifulSoup
import requests
import pandas as pd


url = 'https://lhr.nu.edu.pk/faculty/'
source = requests.get(url)

soup = BeautifulSoup(source.text, 'html.parser')

faculty_section = soup.find('div', id='ee')
faculty_members = faculty_section.find_all('div', class_='col-lg-3 col-md-4 col-sm-6 col-12')

faculty_data = []
No=0

for member in faculty_members:

        No=No+1

        idx=member.find('a',href=True)

        name = member.find('h5', class_='text-center')

        designation = member.find('p')

        email_tag=member.find('p',class_='mb-0 text-center')

        image_tag = member.find('img')
        image_url = image_tag['src'] if image_tag else 'N/A'

        hec_supervisor = 'HEC Approved PhD Supervisor' in member.text

        print("Sr",No)
        print("ID: ",idx['href'].split('/')[-1] if idx else 'N/A')
        print("Name", name.text.strip() if name else 'N/A')
        print("Designation", designation.text.strip() if designation else 'N/A')
        print( "HEC Approved PhD Supervisor", hec_supervisor)
        print("Email", email_tag.text.strip())
        print("Department :", "Department of Electrical Engineering")
        print("ImageURL", image_url)
        print("\n")


        faculty_data.append({
            "Sr": No,
            "ID: ":idx['href'].split('/')[-1] if idx else 'N/A',
            "Name": name.text.strip() if name else 'N/A',
            "Designation": designation.text.strip() if designation else 'N/A',
            "HEC Approved PhD Supervisor": hec_supervisor,
            "Email": email_tag.text.strip(),
            "Department": "Department of Electrical Engineering",
            "ImageURL": image_url
        })

df = pd.DataFrame(faculty_data)

df.to_csv('ee.csv',index=False)

print("Data saved to ee.csv😃")
# Out:
# Sr 1
# ID:  4198
# Name Dr. Saima Zafar
# Designation Professor & HOD
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email saima.zafar@nu.edu.pk
# Department : Department of Electrical Engineering
# ImageURL /media/Faculty/98._Dr_Saima_Zafar_Prof._EE.JPG
#
#
# Sr 2
# ID:  4108
# Name Dr. S.M. Sajid
# Designation Professor
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email sm.sajid@nu.edu.pk
# Department : Department of Electrical Engineering
# ImageURL /media/Faculty/99._Dr_S_M_Sajid_Prof._EE.JPG
#
#
# Sr 3
# ID:  5421
# Name Dr. Syed Aun Abbas
# Designation Professor
# HEC Approved PhD Supervisor False
# Email aun.abbas@nu.edu.pk
# Department : Department of Electrical Engineering
# ImageURL /media/Faculty/100._Dr_Syed_Aun_Abbas_Prof._EE.JPG
#
#
# Sr 4
# ID:  4609
# Name Dr. Omer Saleem
# Designation Associate Professor
#
#                           HEC Approved PhD Supervisor
# ...

# %%
#Step 1: CV

from bs4 import BeautifulSoup
import requests
import pandas as pd


url = 'https://lhr.nu.edu.pk/faculty/'
source = requests.get(url)

soup = BeautifulSoup(source.text, 'html.parser')

faculty_section = soup.find('div', id='cv')
faculty_members = faculty_section.find_all('div', class_='col-lg-3 col-md-4 col-sm-6 col-12')

faculty_data = []
No=0

for member in faculty_members:

        No=No+1

        idx=member.find('a',href=True)

        name = member.find('h5', class_='text-center')

        designation = member.find('p')

        email_tag=member.find('p',class_='mb-0 text-center')

        image_tag = member.find('img')
        image_url = image_tag['src'] if image_tag else 'N/A'

        hec_supervisor = 'HEC Approved PhD Supervisor' in member.text

        print("Sr",No)
        print("ID: ",idx['href'].split('/')[-1] if idx else 'N/A')
        print("Name", name.text.strip() if name else 'N/A')
        print("Designation", designation.text.strip() if designation else 'N/A')
        print( "HEC Approved PhD Supervisor", hec_supervisor)
        print("Email", email_tag.text.strip())
        print("Department :", "Department of Civil Engineering")
        print("ImageURL", image_url)
        print("\n")


        faculty_data.append({
            "Sr": No,
            "ID: ":idx['href'].split('/')[-1] if idx else 'N/A',
            "Name": name.text.strip() if name else 'N/A',
            "Designation": designation.text.strip() if designation else 'N/A',
            "HEC Approved PhD Supervisor": hec_supervisor,
            "Email": email_tag.text.strip(),
            "Department": "Department of Civil Engineering",
            "ImageURL": image_url
        })

df = pd.DataFrame(faculty_data)

df.to_csv('cv.csv',index=False)

print("Data saved to cv.csv😃")
# Out:
# Sr 1
# ID:  5818
# Name Dr. Tauqir Ahmed
# Designation Associate Professor & HOD
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email tauqir.ahmed@nu.edu.pk
# Department : Department of Civil Engineering
# ImageURL /media/Faculty/77._Dr_Tauqir_Ahmed_Prof._CvL.jpg
#
#
# Sr 2
# ID:  9451
# Name Dr. Shahid Ali
# Designation Professor
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email shahid.ali@nu.edu.pk
# Department : Department of Civil Engineering
# ImageURL /media/Faculty/78._Dr_Shahid_Ali_Prof._CvL.JPG
#
#
# Sr 3
# ID:  5705
# Name Dr. Syed Ali Rizwan Bukhari
# Designation Professor
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email syed.ali@nu.edu.pk
# Department : Department of Civil Engineering
# ImageURL /media/Faculty/79._Dr_Syed_Ali_Rizwan_Prof._CvL.JPG
#
#
# Sr 4
# ID:  6941
# Name Dr. Muhammad Azam
# ...

# %%
#Step 1: FSM

from bs4 import BeautifulSoup
import requests
import pandas as pd


url = 'https://lhr.nu.edu.pk/faculty/'
source = requests.get(url)

soup = BeautifulSoup(source.text, 'html.parser')

faculty_section = soup.find('div', id='fsm')
faculty_members = faculty_section.find_all('div', class_='col-lg-3 col-md-4 col-sm-6 col-12')

faculty_data = []
No=0

for member in faculty_members:

        No=No+1

        idx=member.find('a',href=True)

        name = member.find('h5', class_='text-center')

        designation = member.find('p')

        email_tag=member.find('p',class_='mb-0 text-center')

        image_tag = member.find('img')
        image_url = image_tag['src'] if image_tag else 'N/A'

        hec_supervisor = 'HEC Approved PhD Supervisor' in member.text

        print("Sr",No)
        print("ID: ",idx['href'].split('/')[-1] if idx else 'N/A')
        print("Name", name.text.strip() if name else 'N/A')
        print("Designation", designation.text.strip() if designation else 'N/A')
        print( "HEC Approved PhD Supervisor", hec_supervisor)
        print("Email", email_tag.text.strip())
        print("Department :", "Fast School of Management")
        print("ImageURL", image_url)
        print("\n")


        faculty_data.append({
            "Sr": No,
            "ID: ":idx['href'].split('/')[-1] if idx else 'N/A',
            "Name": name.text.strip() if name else 'N/A',
            "Designation": designation.text.strip() if designation else 'N/A',
            "HEC Approved PhD Supervisor": hec_supervisor,
            "Email": email_tag.text.strip(),
            "Department": "Fast School of Management",
            "ImageURL": image_url
        })

df = pd.DataFrame(faculty_data)

df.to_csv('fsm.csv',index=False)

print("Data saved to fsm.csv😃")
# Out:
# Sr 1
# ID:  3924
# Name Dr. Hamid Hassan
# Designation Professor & HOD
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email hamid.hassan@nu.edu.pk
# Department : Fast School of Management
# ImageURL /media/Faculty/121._Dr_Hamid_Hassan_Prof_MG.JPG
#
#
# Sr 2
# ID:  4685
# Name Dr. Akbar Azam
# Designation Associate Professor
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email akbar.azam@nu.edu.pk
# Department : Fast School of Management
# ImageURL /media/Faculty/122.Dr_Akbar_Azam_Assoc._Prof._MG.png
#
#
# Sr 3
# ID:  6563
# Name Dr. Amna Farrukh
# Designation Assistant Professor
#
#
#                           On Leave
# HEC Approved PhD Supervisor False
# Email amna.farrukh@nu.edu.pk
# Department : Fast School of Management
# ImageURL /media/Faculty/126._Amna_Farrukh_Assit_Prof._MG.png
#
#
# Sr 4
# ID:  5712
# Name Dr. Brig Mujahid Hussain
# Designation Assistant Professor
#
# ...

# %%
#Step 1: SS

from bs4 import BeautifulSoup
import requests
import pandas as pd


url = 'https://lhr.nu.edu.pk/faculty/'
source = requests.get(url)

soup = BeautifulSoup(source.text, 'html.parser')

faculty_section = soup.find('div', id='ss')
faculty_members = faculty_section.find_all('div', class_='col-lg-3 col-md-4 col-sm-6 col-12')

faculty_data = []
No=0

for member in faculty_members:

        No=No+1

        idx=member.find('a',href=True)

        name = member.find('h5', class_='text-center')

        designation = member.find('p')

        email_tag=member.find('p',class_='mb-0 text-center')

        image_tag = member.find('img')
        image_url = image_tag['src'] if image_tag else 'N/A'

        hec_supervisor = 'HEC Approved PhD Supervisor' in member.text

        print("Sr",No)
        print("ID: ",idx['href'].split('/')[-1] if idx else 'N/A')
        print("Name", name.text.strip() if name else 'N/A')
        print("Designation", designation.text.strip() if designation else 'N/A')
        print( "HEC Approved PhD Supervisor", hec_supervisor)
        print("Email", email_tag.text.strip())
        print("Department :", "Department of Science and Humanities")
        print("ImageURL", image_url)
        print("\n")


        faculty_data.append({
            "Sr": No,
            "ID: ":idx['href'].split('/')[-1] if idx else 'N/A',
            "Name": name.text.strip() if name else 'N/A',
            "Designation": designation.text.strip() if designation else 'N/A',
            "HEC Approved PhD Supervisor": hec_supervisor,
            "Email": email_tag.text.strip(),
            "Department": "Department of Science and Humanities",
            "ImageURL": image_url
        })

df = pd.DataFrame(faculty_data)

df.to_csv('ss.csv',index=False)

print("Data saved to ss.csv😃")
# Out:
# Sr 1
# ID:  4332
# Name Dr. Mubashir Qayyum
# Designation Professor & HOD
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email mubashir.qayyum@nu.edu.pk
# Department : Department of Science and Humanities
# ImageURL /media/Faculty/149._Dr_Mubashir_Qayyum_Prof._SH.JPG
#
#
# Sr 2
# ID:  4020
# Name Dr. Akhlaq Ahmad Bhatti
# Designation Professor
#                           Dean (Faculty of Sciences & Humanities)
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email akhlaq.ahmad@nu.edu.pk
# Department : Department of Science and Humanities
# ImageURL /media/Faculty/150._Dr._Akhlaq_Ahmad_Bhatti_Prof._SH.JPG
#
#
# Sr 3
# ID:  3712
# Name Dr. Mazhar Hussain
# Designation Professor
#
#                           HEC Approved PhD Supervisor
# HEC Approved PhD Supervisor True
# Email mazhar.hussain@nu.edu.pk
# Department : Department of Science and Humanities
# ...

# %%
#Step no 2: Getting Extension and Latest Education

import pandas as pd
import requests
from bs4 import BeautifulSoup


fsc = pd.read_csv('fsc.csv')
ee = pd.read_csv('ee.csv')
cv = pd.read_csv('cv.csv')
fsm = pd.read_csv('fsm.csv')
ss = pd.read_csv('ss.csv')


def scrape(df,name):

    id_list = df['ID: '].tolist()

    results = []

    for id in id_list:

        url = f'http://lhr.nu.edu.pk/{name}/facultyProfile/{id}'

        response = requests.get(url)

        soup = BeautifulSoup(response.content, 'html.parser')

       #For Extension
        extension="N/A"
        phone_section = soup.find('p', class_='mt-0 text-center')
        phone_text = phone_section.find('span', class_='small').text
        extension = phone_text.split("Ext:")[1].strip() if "Ext:" in phone_text else "N/A"

        #For Highest Education
        education_latest="N/A"
        education_section = soup.find('div', class_='col-lg-8 col-md-6 col-sm-12 text-justify')
        if education_section:
            education_ul = education_section.find('ul')
            if education_ul:
                education_items = education_ul.find_all('li')
                if education_items:
                    education_latest = education_items[0].text.strip()



       #In this I am not printing results because they are too many i am instead direct appending them to files
        results.append({
                'ID: ': id,
                'Extension': extension,
                'Highest Education': education_latest
            })


    faculty_df = pd.DataFrame(results)

    faculty_df.to_csv(f'{name}_2.csv',index=False)
    print(f'Data saved to {name}_2.csv 🤧')



scrape(fsc, 'fsc')
scrape(ee, 'ee')
scrape(cv, 'cv')
scrape(fsm, 'fsm')
scrape(ss, 'ss')
# Out:
# Data saved to fsc_2.csv 🤧
# Data saved to ee_2.csv 🤧
# Data saved to cv_2.csv 🤧
# Data saved to fsm_2.csv 🤧
# Data saved to ss_2.csv 🤧

# %%
#Step 3 Mergeing all files

fsc = pd.read_csv('fsc.csv')
fsc_2 = pd.read_csv('fsc_2.csv')

ee = pd.read_csv('ee.csv')
ee_2 = pd.read_csv('ee_2.csv')

cv = pd.read_csv('cv.csv')
cv_2 = pd.read_csv('cv_2.csv')

fsm = pd.read_csv('fsm.csv')
fsm_2 = pd.read_csv('fsm_2.csv')

ss = pd.read_csv('ss.csv')
ss_2 = pd.read_csv('ss_2.csv')


fsc_merged = pd.merge(fsc, fsc_2, how='left', on='ID: ')
ee_merged = pd.merge(ee, ee_2, how='left', on='ID: ')
cv_merged = pd.merge(cv, cv_2, how='left', on='ID: ')
fsm_merged = pd.merge(fsm, fsm_2, how='left', on='ID: ')
ss_merged = pd.merge(ss, ss_2, how='left', on='ID: ')


all_faculty_data = pd.concat([fsc_merged, ee_merged, cv_merged, fsm_merged, ss_merged], ignore_index=True)

all_faculty_data.to_csv('fast_lhr_faculty.csv', index=False)

print("All Faculty Data Saved to fast_lhr_faculty.csv 😩")
# Out:
# All Faculty Data Saved to fast_lhr_faculty.csv 😩
